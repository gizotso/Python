# %% [markdown]
# # Pandas

# %%
# from matplotlib import pyplot as plt
# plt.rcParams['figure.dpi'] = 80

import pandas as pd

penguins = pd.read_csv("../datasets/penguins_classification.csv")
penguins.head(10)
_ = penguins.hist(figsize=(8, 4), bins=20)

# %%
penguins.describe()
# by default summarize only numerics
# penguins.describe(include='all')
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)
# count          342.000000         342.000000
# mean            43.921930          17.151170
# std              5.459584           1.974793
# min             32.100000          13.100000
# 25%             39.225000          15.600000
# 50%             44.450000          17.300000
# 75%             48.500000          18.700000
# max             59.600000          21.500000

# %%
penguins.dtypes
# Out:
# Culmen Length (mm)    float64
# Culmen Depth (mm)     float64
# Species                object
# dtype: object

# %%
# summary of strings
penguins.describe(include='object')
#penguins['Species'].describe()
# Out:
#        Species
# count      342
# unique       3
# top     Adelie
# freq       151

# %%
penguins["Species"].value_counts()
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: Species, dtype: int64

# %%
_ = penguins["Species"].value_counts().plot(kind= 'bar')
# _ = penguins.Species.value_counts().plot(kind= 'bar')

# %%
penguins["Species"].value_counts().plot.bar(x = "Species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(4,3))
# Plot a histogram
var = penguins['Culmen Length (mm)']
plt.boxplot(var)
# Add titles and labels
plt.title('Data Distribution')
plt.show()

# %%
from matplotlib import pyplot as plt
#import matplotlib as mpl

var = penguins['Culmen Length (mm)']

plt.style.use('seaborn-dark')

# Create a Figure
fig = plt.figure(figsize=(4,3))
# Plot a histogram
plt.boxplot(var, patch_artist=True)
# Add titles and labels
plt.title('Data Distribution')

# Show the figure
#fig.show()
plt.show()

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl

import pandas as pd
penguins = pd.read_csv("../datasets/penguins_classification.csv")

# Get the variable to examine
var = penguins['Culmen Length (mm)']

# mpl.rcdefaults()
# mpl.rc_file_defaults()
# default dpi is 72 for matplotlib
# plt.rcParams['figure.dpi'] = 80
# plt.rcParams['figure.figsize'] = [8.0, 6.0]
# plt.rcParams["figure.autolayout"] = True
plt.style.use('default')
# plt.style.use('seaborn-darkgrid')

# Create a Figure
fig = plt.figure(figsize=(4,3))
# Plot a histogram
plt.boxplot(var)
# Add titles and labels
plt.title('Data Distribution')

# Show the figure
#fig.show()
plt.show()

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
_ = plt.rcParams

# %%
# matplotlib styles : https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
styles = plt.style.available # default, classic + {seaborn, seaborn-dark, ggplot, ...}
# styles

mpl.style.core.STYLE_BLACKLIST
# Out:
# {'backend',
#  'backend_fallback',
#  'datapath',
#  'date.epoch',
#  'docstring.hardcopy',
#  'figure.max_open_warning',
#  'figure.raise_window',
#  'interactive',
#  'savefig.directory',
#  'timezone',
#  'tk.window_focus',
#  'toolbar',
#  'webagg.address',
#  'webagg.open_in_browser',
#  'webagg.port',
#  'webagg.port_retries'}

# %% [markdown]
# Temporary styling :
# ```py
# with plt.style.context('seaborn'):
#     plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
# plt.show()
# ```

# %%
from matplotlib import pyplot as plt

# Get the variable to examine
var = penguins['Culmen Length (mm)']

# plt.style.use('ggplot')
plt.style.use('seaborn')

# Create a Figure
fig = plt.figure(figsize=(6,4))
# Plot a histogram
plt.hist(var, bins = 20)
#plt.hist(var, bins=30, normed=True, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none')

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel(' Culmen Length')
plt.ylabel('mm')
# Show the figure
fig.show()
# Out:
# C:\Users\urrutiaa\AppData\Local\Temp\FreeCommanderPortableTemp\ipykernel_20980\2305408249.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def show_distribution(var_data):
    from matplotlib import pyplot as plt

    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))

    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (8,4),  gridspec_kw={'height_ratios': [2, 1]} )
       # gridspec_kw makes possible different sizes for subplots (e.g. gridspec_kw={'width_ratios': [3, 1]} )
       # https://matplotlib.org/3.1.0/gallery/subplots_axes_and_figures/subplots_demo.html

    # Plot the histogram   
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')

    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot   
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')

    # Add a title to the Figure
    fig.suptitle('Data Distribution')

    # Show the figure
    fig.show()

# Get the variable to examine
col = penguins['Culmen Length (mm)']
# Call the function
show_distribution(col)
# Out:
# Minimum:32.10
# Mean:43.92
# Median:44.45
# Mode:41.10
# Maximum:59.60
# C:\Users\urrutiaa\AppData\Local\Temp\FreeCommanderPortableTemp\ipykernel_1576\1936290788.py:41: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=30)

x1 = penguins[penguins['Species'] == 'Adelie']['Culmen Length (mm)']
x2 = penguins[penguins['Species'] == 'Gentoo']['Culmen Length (mm)']
x3 = penguins[penguins['Species'] == 'Chinstrap']['Culmen Length (mm)']

plt.figure(figsize=(6,4))
_ = plt.hist(x1, **kwargs)
_ = plt.hist(x2, **kwargs)
_ = plt.hist(x3, **kwargs)

# %% [markdown]
# ### Manage colors
# https://stackoverflow.com/questions/20289091/python-matplotlib-filled-boxplots

# %% [markdown]
# # Seaborn
# https://seaborn.pydata.org/tutorial/distributions.html

# %%
df = pd.DataFrame(penguins["Species"].value_counts(), columns = ['i', 'Species'])
#sns.barplot(x=df.index, y=df.Species)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('dark') #white, dark, whitegrid, darkgrid, ticks

plt.figure(figsize=(5,3))
ax = sns.barplot(x=df.index, y=df.Species)

for p,count in zip(ax.patches, df['Species']):
    ax.annotate(count, xy=(p.get_x()+p.get_width()/2, p.get_height()),
                ha='center', va='bottom')

# %%
plt.figure(figsize=(6,4))

num_cols = ['Culmen Length (mm)','Culmen Depth (mm)']

import seaborn as sns
sns.set_style('darkgrid')
sns.histplot(penguins[num_cols] , bins =20)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.displot(penguins, x='Culmen Length (mm)', bins = 15)
# bins=20
# binwidth=3
# bins=[1, 2, 3, 4, 5, 6, 7] when you want to choose bins
# discrete=True

# %%
sns.displot(penguins, x='Culmen Length (mm)', bins = 15, hue = "Species")

# %%
sns.displot(penguins, x='Culmen Length (mm)', bins = 15, hue = "Species",
            element = "step")
            #  multiple="stack")

# %%
sns.displot(penguins, x='Culmen Length (mm)', bins = 15, col = "Species")

# %%
sns.displot(penguins, x='Culmen Length (mm)',hue = "Species", kind="kde", fill=True)
# bw_adjust=.25
# bw_adjust=2

# %%
fig, ax = plt.subplots()
sns.violinplot(data=penguins, x='Species', y='Culmen Length (mm)', inner="points", ax=ax)   

fig.show()
# Out:
# C:\Users\urrutiaa\AppData\Local\Temp\FreeCommanderPortableTemp\ipykernel_8720\242091528.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# https://www.geeksforgeeks.org/box-plot-visualization-with-pandas-and-seaborn/
# box plot with seaborn

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.distplot(penguins['Culmen Length (mm)'])
# Out:
# c:\Tools\Python\Miniconda3\envs\py39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Culmen Length (mm)', ylabel='Density'>

# %%
# Density Plot and Histogram : displot is deprecated
sns.distplot(penguins['Culmen Length (mm)'],
             hist=True, kde=True, rug=True,
             bins=20, color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3})
# Out:
# c:\Tools\Python\Miniconda3\envs\py39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Tools\Python\Miniconda3\envs\py39\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Culmen Length (mm)', ylabel='Density'>

# %%
# Density Plot and Histogram 
#sns.set_theme()
sns.displot(penguins,
            x='Culmen Length (mm)',
            kind='hist', kde=True, rug=False,
             bins=20, 
             )
sns.rugplot(data=penguins, x="Culmen Length (mm)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\urrutiaa\GIT\Python\NoteBooks\Viz-Histogram.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/urrutiaa/GIT/Python/NoteBooks/Viz-Histogram.ipynb#ch0000004?line=0'>1</a> # Density Plot and Histogram
#       <a href='vscode-notebook-cell:/c%3A/Users/urrutiaa/GIT/Python/NoteBooks/Viz-Histogram.ipynb#ch0000004?line=1'>2</a> #sns.set_theme()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/urrutiaa/GIT/Python/NoteBooks/Viz-Histogram.ipynb#ch0000004?line=2'>3</a> sns.displot(penguins,
#       <a href='vscode-notebook-cell:/c%3A/Users/urrutiaa/GIT/Python/NoteBooks/Viz-Histogram.ipynb#ch0000004?line=3'>4</a>             x='Culmen Length (mm)',
# ...

# %%
import matplotlib as mpl

# mpl.rc_file_defaults()

# Differences between current params and `Default`
for key in mpl.rcParamsDefault:
    if not mpl.rcParamsDefault[key] == mpl.rcParams[key]:
        print(key, mpl.rcParamsDefault[key], mpl.rcParams[key])
# Out:
# axes.axisbelow line True
# axes.edgecolor black white
# axes.facecolor white #EAEAF2
# axes.labelcolor black .15
# font.sans-serif ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif'] ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif']
# grid.color #b0b0b0 white
# image.cmap viridis rocket
# interactive False True
# lines.solid_capstyle CapStyle.projecting CapStyle.round
# patch.edgecolor black w
# patch.force_edgecolor False True
# text.color black .15
# xtick.bottom True False
# xtick.color black .15
# ytick.color black .15
# ytick.left True False
